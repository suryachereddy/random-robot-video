# %%
from simulator.sim import render
# Out:
# Unable to load module hid, required to interface with SpaceMouse.
#
#            Only Mac OS X is officially supported. Install the additional
#
#            requirements with `pip install -r requirements-extra.txt`
# ...

# %%
robot=render()
from time import time
robot.randomAction(render=True,frames=120,debug=False,tests=1,save_path="./robotvideos/video",isDomainRandomization=False)
# Out:
# ...
# Creating window glfw
# 100%|██████████| 1/1 [00:04<00:00,  4.81s/it]

# %%
import numpy as np
video=np.load("./robotvideos/video_0.npy",allow_pickle=True)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
import scipy.ndimage
imgplot = plt.imshow(scipy.ndimage.rotate(video[50],180))

# %%
video.shape
# Out:
# (60, 256, 256, 3)
